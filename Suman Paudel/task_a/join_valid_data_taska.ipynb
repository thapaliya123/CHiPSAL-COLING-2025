# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive"

# %%
import  pandas as pd
import glob

files = sorted(glob.glob(f'/content/drive/MyDrive/NLP Competition/Suman Paudel/task_a/datasets/*.csv'))

# %%
files
# Out:
# ['/content/drive/MyDrive/NLP Competition/Suman Paudel/task_a/datasets/SubTask-A-train.csv',
#  '/content/drive/MyDrive/NLP Competition/Suman Paudel/task_a/datasets/Task-A(index,label)val.csv',
#  '/content/drive/MyDrive/NLP Competition/Suman Paudel/task_a/datasets/Task-A(index,text)val.csv',
#  '/content/drive/MyDrive/NLP Competition/Suman Paudel/task_a/datasets/merged_validation.csv']

# %%
output_path = '/content/drive/MyDrive/NLP Competition/Suman Paudel/task_a/datasets/'

# %%
df_labelled_val = pd.read_csv(files[1])
df_text_val = pd.read_csv(files[2])

# %%
df_labelled_val.head()
# Out:
#    index  label
# 0  10015      0
# 1  10016      0
# 2  10020      0
# 3  10022      0
# 4  10031      0

# %%
df_text_val.head()
# Out:
#    index                                               text
# 0  10015  आरजू देउवा घरबाट ननिस्केको कती भो? अंझैपनी रां...
# 1  10016  अब नेपाली जनता बुझ्ने भइसके कसैले मेरो पार्टीक...
# 2  10020  हप्तापछिको समाचार अघिल्लो निर्वाचनमा भन्दा यो ...
# 3  10022  यो पटक को चुनाबी नतिजाबालेन: हजारसिङ: हजारबिस्...
# 4  10031  त्यसैगरी भक्तपुर नगरपालिका वडा नं मा दुई हजार ...

# %%
merged_df = pd.merge(df_labelled_val,df_text_val, how='inner', on='index')

# %%
merged_df
# Out:
#        index  label                                               text
# 0      10015      0  आरजू देउवा घरबाट ननिस्केको कती भो? अंझैपनी रां...
# 1      10016      0  अब नेपाली जनता बुझ्ने भइसके कसैले मेरो पार्टीक...
# 2      10020      0  हप्तापछिको समाचार अघिल्लो निर्वाचनमा भन्दा यो ...
# 3      10022      0  यो पटक को चुनाबी नतिजाबालेन: हजारसिङ: हजारबिस्...
# 4      10031      0  त्यसैगरी भक्तपुर नगरपालिका वडा नं मा दुई हजार ...
# ...      ...    ...                                                ...
# 11228  84881      1  सर्व उद्योगपती, कामगार, विद्यार्थी यांना एकच स...
# 11229  84882      1  मांडवे येथील अहिल्याबाई होळकर यांच्या स्मारकास...
# 11230  84884      1  पोलिसभरती प्रक्रिया जुन्या निकषांनुसार व्हावी ...
# 11231  84885      1  हा निधी उद्ध्वस्त झालेल्या कुटुंबांमधील मुलांच...
# 11232  84888      1  इंटरनॅशनल इन्स्टिट्यूट ऑफ स्पोर्टस्‌ मॅनेजमेंट...
#
# [11233 rows x 3 columns]

# %%
merged_df.to_csv(f'{output_path}/merged_validation.csv', index=False)

# %%
train_set = pd.read_csv(files[0])

# %%
train_set[train_set['label'] == 0].count()
# Out:
# index    12544
# text     12543
# label    12544
# dtype: int64

# %%
train_set.label.value_counts()
# Out:
# label
# 0    12544
# 1    11034
# 2    10996
# 3    10184
# 4     7664
# Name: count, dtype: int64

# %%
merged_df.shape
# Out:
# (11233, 3)

# %%
# %pip install datasets huggingface
from datasets import load_dataset
datasets = load_dataset("rahular/varta")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.3/474.3 kB 15.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 15.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 17.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.
# ...
